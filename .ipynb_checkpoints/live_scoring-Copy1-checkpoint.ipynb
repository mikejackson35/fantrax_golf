# %%
import pandas as pd
import numpy as np
import plotly.express as px
import streamlit as st
import altair as alt

# %%
def get_projections():
    live = pd.read_csv(r"https://feeds.datagolf.com/preds/live-tournament-stats?stats=sg_putt,sg_arg,sg_app,sg_ott,sg_t2g,sg_bs,sg_total,distance,accuracy,gir,prox_fw,prox_rgh,scrambling&round=event_avg&display=value&file_format=csv&key=e297e933c3ad47d71ec1626c299e")#,usecols=['dk_name','total_points'])
    return live
live = get_projections()
dg_proj_copy = live.copy()
live.rename(columns={'player_name':'player'},inplace=True)

# %%
# fix names 'live' vs 'fx'

names = live['player'].str.split(expand=True)
names[0] = names[0].str.rstrip(",")
names[1] = names[1].str.rstrip(",")
names['player'] = names[1] + " " + names[0]
names['player'] = np.where(names['player']=='Min Lee', 'Min Woo Lee', names['player'])
names['player'] = np.where(names['player']=='Byeong An', 'Byeong Hun An', names['player'])
names['player'] = np.where(names['player']=='Rooyen Van', 'Erik Van Rooyen', names['player'])
live = live.set_index(names.player)

# %%
def get_fantrax():
    teams = pd.read_csv(r"fx_wk9.csv",usecols=['Player','Status','Roster Status'])
    return teams
teams = get_fantrax()

# %%
teams.columns = ['player','team','active_reserve']
teams_dict = {'919':'Philly919','u_c':'unit_circle','NT 4':'New Team 4','NT 8':'Sneads Foot','txms':'txmoonshine','MG':'Team Gamble','grrr':'Putt Pirates','[AW]':'AlphaWired'}
teams['team'] = teams.team.map(teams_dict)
teams = teams.loc[teams.active_reserve=='Active'].set_index('player')

# %%
live_merged = pd.merge(teams, live, how='left', left_index=True, right_index=True)[['player','team','position','total','round','thru','sg_putt','sg_t2g','sg_total','gir']].fillna(0).sort_values('total')
live_merged['holes_remaining'] = (72 - (live_merged['thru']).fillna(0))
live_merged['holes_remaining'] = np.where(live_merged['position']=='CUT',0,live_merged['holes_remaining']).astype('int')
live_merged = live_merged.reset_index(drop=True)

# %%
live_merged.head()
# Out:
#              player         team position  total  round  thru  sg_putt  \
# 0      Lee, Min Woo  unit_circle       T2  -14.0   -4.0  18.0   0.2450
# 1  Van Rooyen, Erik   New Team 4       T2  -14.0   -8.0  18.0   1.9550
# 2       Knapp, Jake  unit_circle       T4  -13.0   -5.0  18.0   0.3675
# 3      Lowry, Shane  unit_circle       T4  -13.0    0.0  18.0   0.8275
# 4    Young, Cameron   New Team 4       T4  -13.0   -5.0  18.0   0.9750
#
#    sg_t2g  sg_total       gir  holes_remaining
# 0  2.1700     2.415  0.638890               54
# 1  0.4625     2.415  0.750003               54
# 2  1.8000     2.165  0.708333               54
# 3  1.3375     2.165  0.805555               54
# 4  1.1900     2.165  0.791665               54

# %%
team_color={
                "Philly919": 'rgb(127,60,141)',
                "unit_cirle": 'rgb(17,165,121)',
                "AlphaWired": 'rgb(57,105,172)',
                "Sneads Foot": 'rgb(242,183,1)',
                "New Team 4": 'rgb(231,63,116)',
                "Team Gamble": 'rgb(230,131,16)',
                "txmoonshine": 'rgb(0,134,139)',
                "Putt Pirates": 'rgb(165,170,153)'}

# %%
def highlight_rows(row):
    value = row.loc['Team']
    if value == 'unit_circle':
        color = '#FF99FF' # Pink
    elif value == 'Philly919':
        color = '#7f3c8d' # Purple
    elif value == 'AlphaWired':
        color = '#3969ac' # Blue
    elif value == 'Sneads Foot':
        color = '#f2b701' # Gold
    elif value == 'New Team 4':
        color = '#FF6666' # Magenta
    elif value == 'Team Gamble':
        color = '#e68310' # Orange
    elif value == 'txmoonshine':
        color = '#00868b' # Aqua
    else:
        color = '#a5aa99' # Grey
    return ['background-color: {}'.format(color) for r in row]

# %%
# make leaderboard

live_leaderboard = live_merged[['player','team','position','total','round','thru']].fillna(0).sort_values('total')

live_leaderboard[['total','round','thru']] = live_leaderboard[['total','round','thru']].astype('int')

live_leaderboard.rename(columns={'player':'Player','team':'Team','position':'Pos','total':'Total','round':'Round','thru':'Thru'}).style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_cc66f_row0_col0, #T_cc66f_row0_col1, #T_cc66f_row0_col2, #T_cc66f_row0_col3, #T_cc66f_row0_col4, #T_cc66f_row0_col5, #T_cc66f_row2_col0, #T_cc66f_row2_col1, #T_cc66f_row2_col2, #T_cc66f_row2_col3, #T_cc66f_row2_col4, #T_cc66f_row2_col5, #T_cc66f_row3_col0, #T_cc66f_row3_col1, #T_cc66f_row3_col2, #T_cc66f_row3_col3, #T_cc66f_row3_col4, #T_cc66f_row3_col5, #T_cc66f_row12_col0, #T_cc66f_row12_col1, #T_cc66f_row12_col2, #T_cc66f_row12_col3, #T_cc66f_row12_col4, #T_cc66f_row12_col5, #T_cc66f_row26_col0, #T_cc66f_row26_col1, #T_cc66f_row26_col2, #T_cc66f_row26_col3, #T_cc66f_row26_col4, #T_cc66f_row26_col5, #T_cc66f_row33_col0, #T_cc66f_row33_col1, #T_cc66f_row33_col2, #T_cc66f_row33_col3, #T_cc66f_row33_col4, #T_cc66f_row33_col5 {
#   background-color: #FF99FF;
# }
# #T_cc66f_row1_col0, #T_cc66f_row1_col1, #T_cc66f_row1_col2, #T_cc66f_row1_col3, #T_cc66f_row1_col4, #T_cc66f_row1_col5, #T_cc66f_row4_col0, #T_cc66f_row4_col1, #T_cc66f_row4_col2, #T_cc66f_row4_col3, #T_cc66f_row4_col4, #T_cc66f_row4_col5, #T_cc66f_row20_col0, #T_cc66f_row20_col1, #T_cc66f_row20_col2, #T_cc66f_row20_col3, #T_cc66f_row20_col4, #T_cc66f_row20_col5, #T_cc66f_row41_col0, #T_cc66f_row41_col1, #T_cc66f_row41_col2, #T_cc66f_row41_col3, #T_cc66f_row41_col4, #T_cc66f_row41_col5, #T_cc66f_row43_col0, #T_cc66f_row43_col1, #T_cc66f_row43_col2, #T_cc66f_row43_col3, #T_cc66f_row43_col4, #T_cc66f_row43_col5, #T_cc66f_row46_col0, #T_cc66f_row46_col1, #T_cc66f_row46_col2, #T_cc66f_row46_col3, #T_cc66f_row46_col4, #T_cc66f_row46_col5 {
#   background-color: #FF6666;
# }
level0_col1" class="col_heading level0 col1" >Team</th>
#       <th id="T_cc66f_level0_col2" class="col_heading level0 col2" >Pos</th>
#       <th id="T_cc66f_level0_col3" class="col_heading level0 col3" >Total</th>
#       <th id="T_cc66f_level0_col4" class="col_heading level0 col4" >Round</th>
#       <th id="T_cc66f_level0_col5" class="col_heading level0 col5" >Thru</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc66f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc66f_row0_col0" class="data row0 col0" >Lee, Min Woo</td>
#       <td id="T_cc66f_row0_col1" class="data row0 col1" >unit_circle</td>
#       <td id="T_cc66f_row0_col2" class="data row0 col2" >T2</td>
#       <td id="T_cc66f_row0_col3" class="data row0 col3" >-14</td>
#       <td id="T_cc66f_row0_col4" class="data row0 col4" >-4</td>
#       <td id="T_cc66f_row0_col5" class="data row0 col5" >18</td>
#     </tr>
#     <tr>
#       <th id="T_cc66f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc66f_row1_col0" class="data row1 col0" >Van Rooyen, Erik</td>
#       <td id="T_cc66f_row1_col1" class="data row1 col1" >New Team 4</td>
#       <td id="T_cc66f_row1_col2" class="data row1 col2" >T2</td>
#       <td id="T_cc66f_row1_col3" class="data row1 col3" >-14</td>
#       <td id="T_cc66f_row1_col4" class="data row1 col4" >-8</td>
#       <td id="T_cc66f_row1_col5" class="data row1 col5" >18</td>
#     </tr>
#     <tr>
#       <th id="T_cc66f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc66f_row2_col0" class="da

# %%
# holes remaining
live_phr = live_merged.groupby('team')[['holes_remaining']].sum().reset_index().rename(columns={'team':'Team','holes_remaining':'PHR','total':'To Par'})
live_phr.sort_values(by='PHR').style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_ac208_row0_col0, #T_ac208_row0_col1 {
#   background-color: #FF6666;
# }
# #T_ac208_row1_col0, #T_ac208_row1_col1 {
#   background-color: #7f3c8d;
# }
# #T_ac208_row2_col0, #T_ac208_row2_col1 {
#   background-color: #e68310;
# }
# #T_ac208_row3_col0, #T_ac208_row3_col1 {
#   background-color: #f2b701;
# }
# #T_ac208_row4_col0, #T_ac208_row4_col1 {
#   background-color: #a5aa99;
# }
# #T_ac208_row5_col0, #T_ac208_row5_col1 {
#   background-color: #FF99FF;
# }
# #T_ac208_row6_col0, #T_ac208_row6_col1 {
#   background-color: #00868b;
# }
# #T_ac208_row7_col0, #T_ac208_row7_col1 {
#   background-color: #3969ac;
# }
# </style>
# <table id="T_ac208">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac208_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_ac208_level0_col1" class="col_heading level0 col1" >PHR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac208_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ac208_row0_col0" class="data row0 col0" >New Team 4</td>
#       <td id="T_ac208_row0_col1" class="data row0 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ac208_row1_col0" class="data row1 col0" >Philly919</td>
#       <td id="T_ac208_row1_col1" class="data row1 col1" >162</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_ac208_row2_col0" class="data row2 col0" >Team Gamble</td>
#       <td id="T_ac208_row2_col1" class="data row2 col1" >216</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ac208_row3_col0" class="data row3 col0" >Sneads Foot</td>
#       <td id="T_ac208_row3_col1" class="data row3 col1" >270</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_ac208_row4_col0" class="data row4 col0" >Putt Pirates</td>
#       <td id="T_ac208_row4_col1" class="data row4 col1" >360</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_ac208_row5_col0" class="data row5 col0" >unit_circle</td>
#       <td id="T_ac208_row5_col1" class="data row5 col1" >360</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ac208_row6_col0" class="data row6 col0" >txmoonshine</td>
#       <td id="T_ac208_row6_col1" class="data row6 col1" >396</td>
#     </tr>
#     <tr>
#       <th id="T_ac208_level0_row7" class="row_heading level0 row7" >0</th>
#       <td id="T_ac208_row7_col0" class="data row7 col0" >AlphaWired</td>
#       <td id="T_ac208_row7_col1" class="data row7 col1" >432</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Team Score bar

thru_cut_df = live_leaderboard.groupby('team')['total'].sum().sort_values()

thru_cut_bar = px.bar(thru_cut_df,
                     template='presentation',
                     labels={'value':'','team':''},
                     text_auto=True,
                     height=250,
                     title='Team Score to Par')

thru_cut_bar.update_layout(showlegend=False,title_x=.25)
thru_cut_bar.update_yaxes(showticklabels=False,showgrid=False)
thru_cut_bar.update_traces(marker_color='rgb(200,200,200)',marker_line_width=1.5, opacity=0.6)

thru_cut_bar.show()
# Out:
# <div>                            <div id="a4740fd9-b975-401e-b884-1ded616ea4a1" class="plotly-graph-div" style="height:250px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4740fd9-b975-401e-b884-1ded616ea4a1")) {                    Plotly.newPlot(                        "a4740fd9-b975-401e-b884-1ded616ea4a1",                        [{"alignmentgroup":"True","hovertemplate":"variable=total<br>=%{y}<extra></extra>","legendgroup":"total","marker":{"color":"rgb(200,200,200)","pattern":{"shape":""},"line":{"width":1.5}},"name":"total","offsetgroup":"total","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["unit_circle","Sneads Foot","Team Gamble","New Team 4","Philly919","txmoonshine","Putt Pirates","AlphaWired"],"xaxis":"x","y":[-47,-35,-30,-23,-15,-2,-1,0],"yaxis":"y","type":"bar","opacity":0.6}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":""}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":""},"showticklabels":false,"showgrid":false},"legend":{"title":{"text":"variable"},"tracegroupgap":0},"title":{"text":"Team Score to Par","x":0.25},"barmode":"relative","height":250,"showlegend":false},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('a4740fd9-b975-401e-b884-1ded616ea4a1');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Thru Cut Bar

thru_cut_df = live_leaderboard[live_leaderboard.position!='CUT']['team'].value_counts()#.rename(columns={'team':'thruCut'})

thru_cut_bar = px.bar(thru_cut_df,
                 template='presentation',
                 labels={'value':'','index':''},
                 text_auto=True,
                 height=250,
                 log_y=True,
                 title='Players Thru the Cut')

thru_cut_bar.update_layout(showlegend=False,title_x=.25)
thru_cut_bar.update_yaxes(showticklabels=False,showgrid=False)
thru_cut_bar.update_traces(marker_color='rgb(200,200,200)',marker_line_width=1.5, opacity=0.6)
# Out:
# <div>                            <div id="5aef0064-6457-4a9a-ac3a-c3f8d30cd824" class="plotly-graph-div" style="height:250px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aef0064-6457-4a9a-ac3a-c3f8d30cd824")) {                    Plotly.newPlot(                        "5aef0064-6457-4a9a-ac3a-c3f8d30cd824",                        [{"alignmentgroup":"True","hovertemplate":"variable=team<br>=%{y}<extra></extra>","legendgroup":"team","marker":{"color":"rgb(200,200,200)","pattern":{"shape":""},"line":{"width":1.5}},"name":"team","offsetgroup":"team","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["unit_circle","txmoonshine","AlphaWired","Sneads Foot","Putt Pirates","Team Gamble","New Team 4","Philly919"],"xaxis":"x","y":[6,6,6,5,5,4,3,3],"yaxis":"y","type":"bar","opacity":0.6}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":""}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":""},"type":"log","showticklabels":false,"showgrid":false},"legend":{"title":{"text":"variable"},"tracegroupgap":0},"title":{"text":"Players Thru the Cut","x":0.25},"barmode":"relative","height":250,"showlegend":false},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('5aef0064-6457-4a9a-ac3a-c3f8d30cd824');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# live sg
live_sg = live_merged[['player','sg_putt','sg_t2g','sg_total','gir']].reset_index(drop=True)
live_sg = live_sg.style.background_gradient(cmap='Greens').format(precision=2)
live_sg
# Out:
# <style type="text/css">
# #T_aa929_row0_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_aa929_row0_col2 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_aa929_row0_col3, #T_aa929_row1_col1, #T_aa929_row1_col3, #T_aa929_row3_col4, #T_aa929_row6_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_aa929_row0_col4, #T_aa929_row19_col4, #T_aa929_row30_col4, #T_aa929_row45_col4, #T_aa929_row46_col4, #T_aa929_row47_col4 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_aa929_row1_col2 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_aa929_row1_col4, #T_aa929_row21_col4 {
#   background-color: #005a24;
#   color: #f1f1f1;
# }
# #T_aa929_row2_col1 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_aa929_row2_col2 {
#   background-color: #006227;
#   color: #f1f1f1;
# }
# #T_aa929_row2_col3, #T_aa929_row3_col3, #T_aa929_row4_col3, #T_aa929_row13_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_aa929_row2_col4, #T_aa929_row7_col4, #T_aa929_row9_col4 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_aa929_row3_col1, #T_aa929_row9_col1 {
#   background-color: #238b45;
#   color: #f1f1f1;
# }
# #T_aa929_row3_col2, #T_aa929_row16_col4, #T_aa929_row42_col4 {
#   background-color: #0d7836;
#   color: #f1f1f1;
# }
# #T_aa929_row4_col1, #T_aa929_row15_col2 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_aa929_row4_col2 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_aa929_row4_col4 {
#   background-color: #00491d;
#   color: #f1f1f1;
# }
# #T_aa929_row5_col1 {
#   background-color: #0e7936;
#   color: #f1f1f1;
# }
# #T_aa929_row5_col2, #T_aa929_row8_col1, #T_aa929_row37_col1 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_aa929_row5_col3, #T_aa929_row6_col3, #T_aa929_row7_col3 {
#   background-color: #087432;
#   color: #f1f1f1;
# }
# #T_aa929_row5_col4, #T_aa929_row8_col4, #T_aa929_row37_col4 {
#   background-color: #006027;
#   color: #f1f1f1;
# }
# #T_aa929_row6_col1, #T_aa929_row18_col2 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_aa929_row6_col4 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_aa929_row7_col1 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_aa929_row7_col2, #T_aa929_row8_col3, #T_aa929_row9_col3, #T_aa929_row10_col3 {
#   background-color: #137d39;
#   color: #f1f1f1;
# }
# #T_aa929_row8_col2 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_aa929_row9_col2 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_aa929_row10_col1 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_aa929_row10_col2, #T_aa929_row42_col2 {
#   background-color: #077331;
#   color: #f1f1f1;
# }
# #T_aa929_row10_col4, #T_aa929_row12_col4, #T_aa929_row15_col4 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_aa929_row11_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_aa929_row11_col2, #T_aa929_row41_col2, #T_aa929_row43_col1 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_aa929_row11_col3 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_aa929_row11_col4, #T_aa929_row14_col4 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_aa929_row12_col1 {
#   background-color: #8ed08b;
#   color: #000000;
# }
# #T_aa929_row12_col2 {
#   background-color: #117b38;
#   color: #f1f1f1;
# }
# #T_aa929_row12_col3, #T_aa929_row13_col3, #T_aa929_row14_col3 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_aa929_row13_col2 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_aa929_row13_col4, #T_aa929_row17_col4 {
#   background-color: #03702e;
#   color: #f1f1f1;
# }
# #T_aa929_row14_col1 {
#   background-color: #2d954d;
#   color: #f1f1f1;
# }
# #T_aa929_row14_col2 {
#   background-color: #50b264;
#   color: #f1f1f1;
# }
# #T_aa929_row15_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_aa929_row15_col3 {
#   background-color: #319a50;
#   color: #f1f1f1;
# }
# #T_aa929_row16_col1 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_aa929_row16_col2, #T_aa929_row44_col1 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_aa929_row16_col3, #T_aa929_row45_col2 {
#   background-color: #3ba458;
#   color: #f1f1f1;
# }
# #T_aa929_row17_col1 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_aa929_row17_col2 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_aa929_row17_col3 {
#   background-color: #66bd6f;
#   color: #f1f1f1;
# }
# #T_aa929_row18_col1 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_aa929_row18_col3 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_aa929_row18_col4, #T_aa929_row20_col4, #T_aa929_row44_col4 {
#   background-color: #208843;
#   color: #f1f1f1;
# }
# #T_aa929_row19_col1 {
#   background-color: #005f26;
#   color: #f1f1f1;
# }
# #T_aa929_row19_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_aa929_row19_col3, #T_aa929_row20_col3, #T_aa929_row21_col3 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_aa929_row20_col1 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_aa929_row20_col2 {
#   background-color: #248c46;
#   color: #f1f1f1;
# }
# #T_aa929_row21_col1 {
#   background-color: #d4eece;
#   color: #000000;
# }
# #T_aa929_row21_col2 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_aa929_row22_col1, #T_aa929_row23_col1, #T_aa929_row24_col1, #T_aa929_row25_col1, #T_aa929_row26_col1, #T_aa929_row27_col1, #T_aa929_row28_col1, #T_aa929_row29_col1, #T_aa929_row31_col1, #T_aa929_row32_col1, #T_aa929_row33_col1, #T_aa929_row34_col1, #T_aa929_row35_col1, #T_aa929_row36_col1, #T_aa929_row38_col1, #T_aa929_row39_col1, #T_aa929_row40_col1 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_aa929_row22_col2, #T_aa929_row23_col2, #T_aa929_row24_col2, #T_aa929_row25_col2, #T_aa929_row26_col2, #T_aa929_row27_col2, #T_aa929_row28_col2, #T_aa929_row29_col2, #T_aa929_row31_col2, #T_aa929_row32_col2, #T_aa929_row33_col2, #T_aa929_row34_col2, #T_aa929_row35_col2, #T_aa929_row36_col2, #T_aa929_row38_col2, #T_aa929_row39_col2, #T_aa929_row40_col2 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_aa929_row22_col3, #T_aa929_row23_col3, #T_aa929_row24_col3, #T_aa929_row25_col3, #T_aa929_row26_col3, #T_aa929_row27_col3, #T_aa929_row28_col3, #T_aa929_row29_col3, #T_aa929_row31_col3, #T_aa929_row32_col3, #T_aa929_row33_col3, #T_aa929_row34_col3, #T_aa929_row35_col3, #T_aa929_row36_col3, #T_aa929_row38_col3, #T_aa929_row39_col3, #T_aa929_row40_col3 {
#   background-color: #40aa5d;
#   color: #f1f1f1;
# }
# #T_aa929_row22_col4, #T_aa929_row23_col4, #T_aa929_row24_col4, #T_aa929_row25_col4, #T_aa929_row26_col4, #T_aa929_row27_col4, #T_aa929_row28_col4, #T_aa929_row29_col4, #T_aa929_row31_col4, #T_aa929_row32_col4, #T_aa929_row33_col4, #T_aa929_row34_col4, #T_aa929_row35_col4, #T_aa929_row36_col4, #T_aa929_row38_col4, #T_aa929_row39_col4, #T_aa929_row40_col4, #T_aa929_row42_col1, #T_aa929_row47_col2, #T_aa929_row47_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_aa929_row30_col1 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_aa929_row30_col2 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_aa929_row30_col3 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_aa929_row37_col2 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_aa929_row37_col3 {
#   background-color: #83cb82;
#   color: #000000;
# }
# #T_aa929_row41_col1, #T_aa929_row43_col2 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_aa929_row41_col3, #T_aa929_row42_col3, #T_aa929_row44_col3 {
#   background-color: #80ca80;
#   color: #000000;
# }
# #T_aa929_row41_col4 {
#   background-color: #29914a;
#   color: #f1f1f1;
# }
# #T_aa929_row43_col3 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_aa929_row43_col4 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_aa929_row44_col2 {
#   background-color: #87cd86;
#   color: #000000;
# }
# #T_aa929_row45_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_aa929_row45_col3, #T_aa929_row46_col3 {
#   background-color: #b5e1ae;
#   color: #000000;
# }
# #T_aa929_row46_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_aa929_row46_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_aa929_row47_col1 {
#   background-color: #9bd696;
#   color: #000000;
# }
# </style>
# <table id="T_aa929">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa929_level0_col0" class=

# %%
print(f"unit_circle has {live_merged[live_merged.team=='unit_circle']['holes_remaining'].sum()} Holes Remaining")
live_merged[live_merged.team=='unit_circle'].drop(columns=['holes_remaining','team'])
# Out:
# unit_circle has 360 Holes Remaining
#             player position  total  round  thru  sg_putt  sg_t2g  sg_total  \
# 0     Lee, Min Woo       T2  -14.0   -4.0  18.0     0.24    2.17      2.42
# 2      Knapp, Jake       T4  -13.0   -5.0  18.0     0.37    1.80      2.16
# 3     Lowry, Shane       T4  -13.0    0.0  18.0     0.83    1.34      2.16
# 12  Conners, Corey      T41   -7.0   -5.0  18.0    -0.61    1.27      0.66
# 29               0        0    0.0    0.0   0.0     0.00    0.00      0.00
# 36               0        0    0.0    0.0   0.0     0.00    0.00      0.00
#
#      gir
# 0   0.64
# 2   0.71
# 3   0.81
# 12  0.76
# 29  0.00
# 36  0.00

# %%
# live look at all 48 active players with player as index

print(f"Philly919 has {live_merged[live_merged.team=='Philly919']['holes_remaining'].sum()} Holes Remaining")
live_merged[live_merged.team=='Philly919'].drop(columns=['holes_remaining','team'])

# %%
# live look at all 48 active players with player as index

print(f"Team Gamble has {live_merged[live_merged.team=='Team Gamble']['holes_remaining'].sum()} Holes Remaining")
live_merged[live_merged.team=='Team Gamble'].drop(columns=['holes_remaining','team'])

# %%
# live look at all 48 active players with player as index

print(f"New Team 4 has {live_merged[live_merged.team=='New Team 4']['holes_remaining'].sum()} Holes Remaining")
live_merged[live_merged.team=='New Team 4'].drop(columns=['holes_remaining','team'])

# %%
unit_circle = teams.loc[(teams.team=='unit_circle') & (teams.active_reserve=='Active')].index

live['thru_hp'] = live['thru'] + 18

# live[live.player.isin([unit_circle])]#[['player','total','round','thru','thru_hp']].reset_index(drop=True)
# Out:
# Index(['Patrick Cantlay', 'Tommy Fleetwood', 'Min Woo Lee', 'Corey Conners',
#        'Shane Lowry', 'Jake Knapp'],
#       dtype='object', name='player')

# %%
active_rosters = []

for team in teams.team.unique():
    one_roster = teams.loc[(teams.team==team) & (teams.active_reserve=='Active')].index
    active_rosters.append(one_roster)

cols = teams.team.unique()
active_rosters = pd.DataFrame(active_rosters, index=cols).T
active_rosters
# Out:
#           AlphaWired      unit_circle     Team Gamble          txmoonshine  \
# 0          Sam Burns  Patrick Cantlay       Eric Cole              Tom Kim
# 1  Xander Schauffele  Tommy Fleetwood   Byeong Hun An      Collin Morikawa
# 2      Jordan Spieth      Min Woo Lee  Stephan Jaeger          J.T. Poston
# 3          Jason Day    Corey Conners  Matthieu Pavon  Matthew Fitzpatrick
# 4       Brian Harman      Shane Lowry        Tom Hoge       Keegan Bradley
# 5     Harris English       Jake Knapp  Chesson Hadley     Nicolai Hojgaard
#
#         Philly919    Sneads Foot             Putt Pirates        New Team 4
# 0       Luke List   Rory McIlroy        Scottie Scheffler     Cameron Young
# 1      Sungjae Im  Rickie Fowler          Sahith Theegala   Erik Van Rooyen
# 2  Russell Henley      Sam Ryder           Will Zalatoris     Akshay Bhatia
# 3      Chris Kirk  Cameron Champ          Emiliano Grillo        Justin Suh
# 4     Justin Rose    Nick Dunlap  Christiaan Bezuidenhout   Camilo Villegas
# 5   Daniel Berger   Parker Coody            Kurt Kitayama  Thorbjorn Olesen
